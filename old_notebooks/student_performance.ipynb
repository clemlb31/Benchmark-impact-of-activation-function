# %% [markdown]
# Exploration of the "Student performance dataset"

# %%
import os
import zipfile
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
import torch as torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from student_performance import student_model, student_preprocessing
from training_functions import train_model, activation_function

# %%
df = pd.read_csv('./data/minahilfatima12328/performance-trends-in-education/StudentPerformanceFactors.csv')
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                  0           Low          Medium
# 1             Yes                  2        Medium          Medium
# 2             Yes                  2        Medium          Medium
# 3             Yes                  1        Medium          Medium
# 4             Yes                  3        Medium            High
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                  3                    No
# 1      Public       Negative                  4                    No
# 2      Public        Neutral                  4                    No
# 3      Public       Negative                  4                    No
# 4      Public        Neutral                  4                    No
#
#   Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# 0              High School               Near    Male          67
# 1                  College           Moderate  Female          61
# 2             Postgraduate               Near    Male          74
# 3              High School           Moderate    Male          71
# 4                  College               Near  Female          70

# %%
df.describe()
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                  0           Low          Medium
# 1             Yes                  2        Medium          Medium
# 2             Yes                  2        Medium          Medium
# 3             Yes                  1        Medium          Medium
# 4             Yes                  3        Medium            High
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                  3                    No
# 1      Public       Negative                  4                    No
# 2      Public        Neutral                  4                    No
# 3      Public       Negative                  4                    No
# 4      Public        Neutral                  4                    No
#
#   Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# 0              High School               Near    Male          67
# 1                  College           Moderate  Female          61
# 2             Postgraduate               Near    Male          74
# 3              High School           Moderate    Male          71
# 4                  College               Near  Female          70

# %%
categorical_vars = [col for col in df.columns if df[col].dtype == pd.CategoricalDtype]
numerical_vars = [col for col in df.columns if df[col].dtype != pd.CategoricalDtype]
categorical_vars, numerical_vars
# Out:
# (['Parental_Involvement',
#   'Access_to_Resources',
#   'Extracurricular_Activities',
#   'Motivation_Level',
#   'Internet_Access',
#   'Family_Income',
#   'Teacher_Quality',
#   'School_Type',
#   'Peer_Influence',
#   'Learning_Disabilities',
#   'Parental_Education_Level',
#   'Distance_from_Home',
#   'Gender'],
#  ['Hours_Studied',
#   'Attendance',
#   'Sleep_Hours',
#   'Previous_Scores',
#   'Tutoring_Sessions',
#   'Physical_Activity',
#   'Exam_Score'])

# %%
mean_df = df[numerical_vars].mean()
std_df = df[numerical_vars].std()

# %%
for col in numerical_vars:
    df[col] = (df[col]-mean_df[col])/std_df[col]

# %%
# sns.histplot(df['Attendance'], bins=10)

# %%
# sns.heatmap(df[numerical_vars])

# %%
# sns.lmplot(data=df, x="Previous_Scores", y="Exam_Score", hue="Parental_Involvement")

# %%
# sns.lmplot(data=df, x="Hours_Studied", y="Exam_Score", hue="Parental_Involvement")

# %%
# sns.regplot(data=df, x="Attendance", y="Exam_Score")

# %%
# sns.regplot(data=df, x="Sleep_Hours", y="Exam_Score")

# %%
# sns.histplot(df['Exam_Score'])

# %%
# sns.swarmplot(data=df, x="Parental_Involvement", y="Exam_Score")

# %%
# sns.swarmplot(data=df, x="Motivation_Level", y="Exam_Score")

# %%
# sns.swarmplot(data=df, x="Teacher_Quality", y="Exam_Score")

# %%
# sns.swarmplot(data=df, x="Learning_Disabilities", y="Exam_Score")

# %%
# sns.swarmplot(data=df, x="Parental_Education_Level", y="Exam_Score")

# %%
# sns.swarmplot(data=df, x="Gender", y="Exam_Score")

# %%
# sns.scatterplot(data=df, x="Hours_Studied", y="Sleep_Hours")

# %%
# sns.scatterplot(data=df, x="Tutoring_Sessions", y="Exam_Score")

# %%
X_train_scaled,X_val_scaled,X_test_scaled,y_train,y_val,y_test, scaler_X, scaler_y = student_preprocessing(df,test_size=0.2,val_size=0.2)

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %%
# Modèle régularisé pour éviter l'overfitting
# Architecture plus petite [64, 32] au lieu de [128, 64, 32]
# Dropout élevé (0.5) pour forte régularisation
model = student_model(
    input_dim=X_train_scaled.shape[1], 
    mode='relu',
    hidden_dims=[64, 32],  # Architecture réduite pour éviter l'overfitting
    dropout_rate=0.5,  # Dropout élevé pour régularisation forte
    use_batch_norm=False  # Désactivé car peut interférer avec dropout élevé
).to(device)

criterion = nn.MSELoss()
learning_rate = 0.001  # Learning rate réduit pour apprentissage plus stable
num_epochs = 100
batch_size = 32

# Optimizer avec weight decay augmenté pour plus de régularisation
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-3)


# Note: y_train, y_val, y_test sont maintenant des numpy arrays (déjà scalés), pas des pandas Series
train_dataset = TensorDataset(torch.tensor(X_train_scaled, dtype=torch.float32).to(device), torch.tensor(y_train, dtype=torch.float32).view(-1, 1).to(device))
val_dataset = TensorDataset(torch.tensor(X_val_scaled, dtype=torch.float32).to(device), torch.tensor(y_val, dtype=torch.float32).view(-1, 1).to(device))
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
history = train_model(model, criterion, optimizer, num_epochs,train_loader, val_loader,device)
# Out:
# Epoch 1/100, Training Loss: 0.8153, Validation Loss: 0.6413
# Epoch 2/100, Training Loss: 0.5180, Validation Loss: 0.4663
# Epoch 3/100, Training Loss: 0.4346, Validation Loss: 0.4476
# Epoch 4/100, Training Loss: 0.3915, Validation Loss: 0.4395
# Epoch 5/100, Training Loss: 0.3746, Validation Loss: 0.4396
# Epoch 6/100, Training Loss: 0.3529, Validation Loss: 0.4301
# Epoch 7/100, Training Loss: 0.3513, Validation Loss: 0.4304
# Epoch 8/100, Training Loss: 0.3309, Validation Loss: 0.4345
# Epoch 9/100, Training Loss: 0.3377, Validation Loss: 0.4287
# Epoch 10/100, Training Loss: 0.3280, Validation Loss: 0.4220
# Epoch 11/100, Training Loss: 0.3464, Validation Loss: 0.4304
# Epoch 12/100, Training Loss: 0.3303, Validation Loss: 0.4279
# Epoch 13/100, Training Loss: 0.3313, Validation Loss: 0.4310
# Epoch 14/100, Training Loss: 0.3270, Validation Loss: 0.4274
# Epoch 15/100, Training Loss: 0.3280, Validation Loss: 0.4219
# Epoch 16/100, Training Loss: 0.3247, Validation Loss: 0.4373
# Epoch 17/100, Training Loss: 0.3284, Validation Loss: 0.4280
# Epoch 18/100, Training Loss: 0.3157, Validation Loss: 0.4220
# Epoch 19/100, Training Loss: 0.3140, Validation Loss: 0.4200
# Epoch 20/100, Training Loss: 0.3119, Validation Loss: 0.4209
# Epoch 21/100, Training Loss: 0.3119, Validation Loss: 0.4199
# Epoch 22/100, Training Loss: 0.3271, Validation Loss: 0.4232
# Epoch 23/100, Training Loss: 0.3141, Validation Loss: 0.4236
# Epoch 24/100, Training Loss: 0.3150, Validation Loss: 0.4252
# Epoch 25/100, Training Loss: 0.3170, Validation Loss: 0.4231
# Epoch 26/100, Training Loss: 0.3189, Validation Loss: 0.4219
# Epoch 27/100, Training Loss: 0.3064, Validation Loss: 0.4232
# Epoch 28/100, Training Loss: 0.3096, Validation Loss: 0.4235
# Epoch 29/100, Training Loss: 0.3022, Validation Loss: 0.4202
# Epoch 30/100, Training Loss: 0.2986, Validation Loss: 0.4241
# Epoch 31/100, Training Loss: 0.3107, Validation Loss: 0.4263
# Epoch 32/100, Training Loss: 0.3013, Validation Loss: 0.4205
# Epoch 33/100, Training Loss: 0.3120, Validation Loss: 0.4212
# Epoch 34/100, Training Loss: 0.3064, Validation Loss: 0.4190
# Epoch 35/100, Training Loss: 0.2958, Validation Loss: 0.4180
# Epoch 36/100, Training Loss: 0.3065, Validation Loss: 0.4199
# Epoch 37/100, Training Loss: 0.2998, Validation Loss: 0.4198
# Epoch 38/100, Training Loss: 0.3020, Validation Loss: 0.4194
# Epoch 39/100, Training Loss: 0.3079, Validation Loss: 0.4249
# Epoch 40/100, Training Loss: 0.3122, Validation Loss: 0.4204
# Epoch 41/100, Training Loss: 0.3027, Validation Loss: 0.4186
# Epoch 42/100, Training Loss: 0.2998, Validation Loss: 0.4258
# Epoch 43/100, Training Loss: 0.3076, Validation Loss: 0.4199
# Epoch 44/100, Training Loss: 0.3066, Validation Loss: 0.4221
# Epoch 45/100, Training Loss: 0.3059, Validation Loss: 0.4196
# Epoch 46/100, Training Loss: 0.3049, Validation Loss: 0.4254
# Epoch 47/100, Training Loss: 0.2984, Validation Loss: 0.4309
# Epoch 48/100, Training Loss: 0.3049, Validation Loss: 0.4225
# Epoch 49/100, Training Loss: 0.3003, Validation Loss: 0.4219
# Epoch 50/100, Training Loss: 0.2966, Validation Loss: 0.4193
# Epoch 51/100, Training Loss: 0.2959, Validation Loss: 0.4161
# Epoch 52/100, Training Loss: 0.2927, Validation Loss: 0.4176
# Epoch 53/100, Training Loss: 0.2977, Validation Loss: 0.4213
# Epoch 54/100, Training Loss: 0.3063, Validation Loss: 0.4193
# Epoch 55/100, Training Loss: 0.3059, Validation Loss: 0.4164
# Epoch 56/100, Training Loss: 0.2961, Validation Loss: 0.4177
# Epoch 57/100, Training Loss: 0.2948, Validation Loss: 0.4213
# Epoch 58/100, Training Loss: 0.2968, Validation Loss: 0.4265
# Epoch 59/100, Training Loss: 0.3028, Validation Loss: 0.4238
# Epoch 60/100, Training Loss: 0.3009, Validation Loss: 0.4179
# Epoch 61/100, Training Loss: 0.2922, Validation Loss: 0.4269
# Epoch 62/100, Training Loss: 0.2966, Validation Loss: 0.4242
# Epoch 63/100, Training Loss: 0.2971, Validation Loss: 0.4243
# Epoch 64/100, Training Loss: 0.3022, Validation Loss: 0.4182
# Epoch 65/100, Training Loss: 0.3012, Validation Loss: 0.4199
# Epoch 66/100, Training Loss: 0.2967, Validation Loss: 0.4215
# Epoch 67/100, Training Loss: 0.3011, Validation Loss: 0.4250
# Epoch 68/100, Training Loss: 0.2927, Validation Loss: 0.4194
# Epoch 69/100, Training Loss: 0.2910, Validation Loss: 0.4245
# Epoch 70/100, Training Loss: 0.2841, Validation Loss: 0.4249
# Epoch 71/100, Training Loss: 0.2967, Validation Loss: 0.4240
# Epoch 72/100, Training Loss: 0.3031, Validation Loss: 0.4209
# Epoch 73/100, Training Loss: 0.2968, Validation Loss: 0.4276
# Epoch 74/100, Training Loss: 0.3018, Validation Loss: 0.4279
# Epoch 75/100, Training Loss: 0.2985, Validation Loss: 0.4236
# Epoch 76/100, Training Loss: 0.2967, Validation Loss: 0.4220
# Epoch 77/100, Training Loss: 0.2924, Validation Loss: 0.4226
# Epoch 78/100, Training Loss: 0.3061, Validation Loss: 0.4302
# Epoch 79/100, Training Loss: 0.2961, Validation Loss: 0.4235
# Epoch 80/100, Training Loss: 0.2923, Validation Loss: 0.4271
# Epoch 81/100, Training Loss: 0.2931, Validation Loss: 0.4234
# Epoch 82/100, Training Loss: 0.2979, Validation Loss: 0.4275
# Epoch 83/100, Training Loss: 0.2945, Validation Loss: 0.4285
# Epoch 84/100, Training Loss: 0.2900, Validation Loss: 0.4216
# Epoch 85/100, Training Loss: 0.2952, Validation Loss: 0.4237
# Epoch 86/100, Training Loss: 0.2941, Validation Loss: 0.4250
# Epoch 87/100, Training Loss: 0.2953, Validation Loss: 0.4265
# Epoch 88/100, Training Loss: 0.2862, Validation Loss: 0.4246
# Epoch 89/100, Training Loss: 0.2949, Validation Loss: 0.4270
# Epoch 90/100, Training Loss: 0.2889, Validation Loss: 0.4215
# Epoch 91/100, Training Loss: 0.2972, Validation Loss: 0.4186
# Epoch 92/100, Training Loss: 0.2783, Validation Loss: 0.4248
# Epoch 93/100, Training Loss: 0.2929, Validation Loss: 0.4239
# Epoch 94/100, Training Loss: 0.2998, Validation Loss: 0.4253
# Epoch 95/100, Training Loss: 0.2906, Validation Loss: 0.4214
# Epoch 96/100, Training Loss: 0.2938, Validation Loss: 0.4205
# Epoch 97/100, Training Loss: 0.3002, Validation Loss: 0.4242
# Epoch 98/100, Training Loss: 0.2812, Validation Loss: 0.4255
# Epoch 99/100, Training Loss: 0.2857, Validation Loss: 0.4250
# Epoch 100/100, Training Loss: 0.2794, Validation Loss: 0.4235
