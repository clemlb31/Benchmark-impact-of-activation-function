# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch.nn as nn
import torch 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from tqdm import tqdm 
from training_functions import train_model
from sklearn.metrics import mean_squared_error

# %%
from torch.utils.data import DataLoader, TensorDataset
from model import preprocess
from model import lstm

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# Data Processing

# %%
df = pd.read_csv('food_price_inflation.csv')
print(df.head())
print(df.shape)
# Out:
#   REF_AREA REF_AREA_LABEL TIME_PERIOD  OBS_VALUE
# 0      AFG    Afghanistan  2001-01-01  22.943765
# 1      AFG    Afghanistan  2001-02-01  24.357903
# 2      AFG    Afghanistan  2001-03-01  21.202933
# 3      AFG    Afghanistan  2001-04-01  17.301832
# 4      AFG    Afghanistan  2001-05-01   9.334624
# (59839, 4)

# %%
# we keep only data in France 
df = df[df['REF_AREA_LABEL'] == 'France']
df = df.drop('REF_AREA', axis=1)
df = df.drop('REF_AREA_LABEL', axis=1)

print(df.head())
print(df.shape)
# Out:
#       TIME_PERIOD  OBS_VALUE
# 19470  2001-01-01   3.542484
# 19471  2001-02-01   3.555150
# 19472  2001-03-01   4.911412
# 19473  2001-04-01   5.140790
# 19474  2001-05-01   6.648663
# (294, 2)

# %% [markdown]
# Training

# %%
# preprocessing 
X_train_scaled,X_val_scaled,X_test_scaled,y_train,y_val,y_test = preprocess(df, split_ratio_train_test=0.8, split_ratio_train_valid=0.8, device=device)
input_size = X_train_scaled.shape[2]

# %%
# training's hyperparameters
model = lstm(input_size=input_size, mode = 'relu').to(device)
criterion = nn.MSELoss()
learning_rate = 0.001
num_epochs = 200
batch_size = 32
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_set = TensorDataset(X_train_scaled, y_train)
train_loader = DataLoader(train_set, batch_size=batch_size)

val_set = TensorDataset(X_val_scaled, y_val)
val_loader = DataLoader(train_set, batch_size=batch_size)

test_set = TensorDataset(X_test_scaled, y_test)
test_loader = DataLoader(test_set, batch_size=batch_size)

# %%
history = train_model(model, criterion, optimizer, num_epochs,train_loader, val_loader)
# Out:
# 200
# Epoch 1/200, Training Loss: 4.6144, Validation Loss: 4.4219
# Epoch 2/200, Training Loss: 4.3437, Validation Loss: 4.1628
# Epoch 3/200, Training Loss: 4.0745, Validation Loss: 3.8483
# Epoch 4/200, Training Loss: 3.7301, Validation Loss: 3.3848
# Epoch 5/200, Training Loss: 3.2186, Validation Loss: 2.7209
# Epoch 6/200, Training Loss: 2.7181, Validation Loss: 2.6474
# Epoch 7/200, Training Loss: 2.6167, Validation Loss: 2.5429
# Epoch 8/200, Training Loss: 2.5604, Validation Loss: 2.5372
# Epoch 9/200, Training Loss: 2.5626, Validation Loss: 2.5239
# Epoch 10/200, Training Loss: 2.5346, Validation Loss: 2.4925
# Epoch 11/200, Training Loss: 2.5049, Validation Loss: 2.4803
# Epoch 12/200, Training Loss: 2.4979, Validation Loss: 2.4678
# Epoch 13/200, Training Loss: 2.4897, Validation Loss: 2.4520
# Epoch 14/200, Training Loss: 2.4763, Validation Loss: 2.4388
# Epoch 15/200, Training Loss: 2.4612, Validation Loss: 2.4255
# Epoch 16/200, Training Loss: 2.4461, Validation Loss: 2.4125
# Epoch 17/200, Training Loss: 2.4328, Validation Loss: 2.3991
# Epoch 18/200, Training Loss: 2.4198, Validation Loss: 2.3845
# Epoch 19/200, Training Loss: 2.4053, Validation Loss: 2.3690
# Epoch 20/200, Training Loss: 2.3893, Validation Loss: 2.3531
# Epoch 21/200, Training Loss: 2.3727, Validation Loss: 2.3366
# Epoch 22/200, Training Loss: 2.3555, Validation Loss: 2.3189
# Epoch 23/200, Training Loss: 2.3373, Validation Loss: 2.2994
# Epoch 24/200, Training Loss: 2.3175, Validation Loss: 2.2782
# Epoch 25/200, Training Loss: 2.2956, Validation Loss: 2.2548
# Epoch 26/200, Training Loss: 2.2714, Validation Loss: 2.2289
# Epoch 27/200, Training Loss: 2.2446, Validation Loss: 2.1993
# Epoch 28/200, Training Loss: 2.2142, Validation Loss: 2.1643
# Epoch 29/200, Training Loss: 2.1782, Validation Loss: 2.1205
# Epoch 30/200, Training Loss: 2.1333, Validation Loss: 2.0604
# Epoch 31/200, Training Loss: 2.0722, Validation Loss: 1.9705
# Epoch 32/200, Training Loss: 1.9825, Validation Loss: 1.8403
# Epoch 33/200, Training Loss: 1.8507, Validation Loss: 1.6668
# Epoch 34/200, Training Loss: 1.6762, Validation Loss: 1.5055
# Epoch 35/200, Training Loss: 1.5142, Validation Loss: 1.3902
# Epoch 36/200, Training Loss: 1.4148, Validation Loss: 1.5031
# Epoch 37/200, Training Loss: 1.7347, Validation Loss: 1.7300
# Epoch 38/200, Training Loss: 2.3924, Validation Loss: 1.4445
# Epoch 39/200, Training Loss: 1.9733, Validation Loss: 1.8094
# Epoch 40/200, Training Loss: 1.6823, Validation Loss: 1.7209
# Epoch 41/200, Training Loss: 1.8132, Validation Loss: 1.5043
# Epoch 42/200, Training Loss: 1.6039, Validation Loss: 1.3524
# Epoch 43/200, Training Loss: 1.2879, Validation Loss: 1.3197
# Epoch 44/200, Training Loss: 1.3271, Validation Loss: 1.1656
# Epoch 45/200, Training Loss: 1.1855, Validation Loss: 1.0785
# Epoch 46/200, Training Loss: 1.0975, Validation Loss: 0.9874
# Epoch 47/200, Training Loss: 1.0136, Validation Loss: 0.9140
# Epoch 48/200, Training Loss: 0.9547, Validation Loss: 0.8563
# Epoch 49/200, Training Loss: 0.8918, Validation Loss: 0.8307
# Epoch 50/200, Training Loss: 0.8589, Validation Loss: 1.2903
# Epoch 51/200, Training Loss: 1.3665, Validation Loss: 1.9789
# Epoch 52/200, Training Loss: 2.3546, Validation Loss: 1.6668
# Epoch 53/200, Training Loss: 1.3703, Validation Loss: 1.0435
# Epoch 54/200, Training Loss: 1.2324, Validation Loss: 1.0764
# Epoch 55/200, Training Loss: 1.1863, Validation Loss: 1.0230
# Epoch 56/200, Training Loss: 1.1894, Validation Loss: 0.9130
# Epoch 57/200, Training Loss: 0.8613, Validation Loss: 0.7985
# Epoch 58/200, Training Loss: 0.8251, Validation Loss: 0.7323
# Epoch 59/200, Training Loss: 0.7479, Validation Loss: 0.7264
# Epoch 60/200, Training Loss: 0.7823, Validation Loss: 0.7052
# Epoch 61/200, Training Loss: 0.8061, Validation Loss: 0.6515
# Epoch 62/200, Training Loss: 0.8108, Validation Loss: 0.7183
# Epoch 63/200, Training Loss: 0.9496, Validation Loss: 0.6351
# Epoch 64/200, Training Loss: 0.7143, Validation Loss: 0.5848
# Epoch 65/200, Training Loss: 0.6025, Validation Loss: 0.5701
# Epoch 66/200, Training Loss: 0.5616, Validation Loss: 0.5620
# Epoch 67/200, Training Loss: 0.5559, Validation Loss: 0.5261
# Epoch 68/200, Training Loss: 0.5292, Validation Loss: 0.4964
# Epoch 69/200, Training Loss: 0.5091, Validation Loss: 0.4779
# Epoch 70/200, Training Loss: 0.4855, Validation Loss: 0.4592
# Epoch 71/200, Training Loss: 0.4707, Validation Loss: 0.4489
# Epoch 72/200, Training Loss: 0.4531, Validation Loss: 0.4467
# Epoch 73/200, Training Loss: 0.4499, Validation Loss: 0.4645
# Epoch 74/200, Training Loss: 0.4586, Validation Loss: 0.5536
# Epoch 75/200, Training Loss: 0.5507, Validation Loss: 0.4279
# Epoch 76/200, Training Loss: 0.4606, Validation Loss: 0.4169
# Epoch 77/200, Training Loss: 0.4459, Validation Loss: 0.4302
# Epoch 78/200, Training Loss: 0.4868, Validation Loss: 0.3708
# Epoch 79/200, Training Loss: 0.4371, Validation Loss: 0.4068
# Epoch 80/200, Training Loss: 0.4687, Validation Loss: 0.4978
# Epoch 81/200, Training Loss: 0.5331, Validation Loss: 0.4279
# Epoch 82/200, Training Loss: 0.4553, Validation Loss: 0.3846
# Epoch 83/200, Training Loss: 0.4158, Validation Loss: 0.3461
# Epoch 84/200, Training Loss: 0.3849, Validation Loss: 0.3444
# Epoch 85/200, Training Loss: 0.3646, Validation Loss: 0.3415
# Epoch 86/200, Training Loss: 0.3611, Validation Loss: 0.3025
# Epoch 87/200, Training Loss: 0.3133, Validation Loss: 0.3066
# Epoch 88/200, Training Loss: 0.3110, Validation Loss: 0.3360
# Epoch 89/200, Training Loss: 0.3261, Validation Loss: 0.2977
# Epoch 90/200, Training Loss: 0.2942, Validation Loss: 0.2981
# Epoch 91/200, Training Loss: 0.2945, Validation Loss: 0.2732
# Epoch 92/200, Training Loss: 0.2716, Validation Loss: 0.2652
# Epoch 93/200, Training Loss: 0.2643, Validation Loss: 0.2569
# Epoch 94/200, Training Loss: 0.2566, Validation Loss: 0.2579
# Epoch 95/200, Training Loss: 0.2555, Validation Loss: 0.2616
# Epoch 96/200, Training Loss: 0.2611, Validation Loss: 0.3159
# Epoch 97/200, Training Loss: 0.3043, Validation Loss: 0.2579
# Epoch 98/200, Training Loss: 0.2559, Validation Loss: 0.2494
# Epoch 99/200, Training Loss: 0.2577, Validation Loss: 0.2437
# Epoch 100/200, Training Loss: 0.2589, Validation Loss: 0.2274
# Epoch 101/200, Training Loss: 0.2730, Validation Loss: 0.3211
# Epoch 102/200, Training Loss: 0.4078, Validation Loss: 0.2561
# Epoch 103/200, Training Loss: 0.4655, Validation Loss: 0.3839
# Epoch 104/200, Training Loss: 0.6477, Validation Loss: 0.2855
# Epoch 105/200, Training Loss: 0.3955, Validation Loss: 0.3869
# Epoch 106/200, Training Loss: 0.3960, Validation Loss: 0.6346
# Epoch 107/200, Training Loss: 0.5806, Validation Loss: 0.2641
# Epoch 108/200, Training Loss: 0.3230, Validation Loss: 0.3469
# Epoch 109/200, Training Loss: 0.3289, Validation Loss: 0.2734
# Epoch 110/200, Training Loss: 0.2840, Validation Loss: 0.2299
# Epoch 111/200, Training Loss: 0.2263, Validation Loss: 0.2198
# Epoch 112/200, Training Loss: 0.2209, Validation Loss: 0.1887
# Epoch 113/200, Training Loss: 0.1882, Validation Loss: 0.1748
# Epoch 114/200, Training Loss: 0.1736, Validation Loss: 0.1702
# Epoch 115/200, Training Loss: 0.1700, Validation Loss: 0.1700
# Epoch 116/200, Training Loss: 0.1684, Validation Loss: 0.1622
# Epoch 117/200, Training Loss: 0.1611, Validation Loss: 0.1615
# Epoch 118/200, Training Loss: 0.1600, Validation Loss: 0.1571
# Epoch 119/200, Training Loss: 0.1560, Validation Loss: 0.1573
# Epoch 120/200, Training Loss: 0.1557, Validation Loss: 0.1501
# Epoch 121/200, Training Loss: 0.1493, Validation Loss: 0.1482
# Epoch 122/200, Training Loss: 0.1471, Validation Loss: 0.1452
# Epoch 123/200, Training Loss: 0.1444, Validation Loss: 0.1466
# Epoch 124/200, Training Loss: 0.1451, Validation Loss: 0.1452
# Epoch 125/200, Training Loss: 0.1436, Validation Loss: 0.1522
# Epoch 126/200, Training Loss: 0.1491, Validation Loss: 0.1479
# Epoch 127/200, Training Loss: 0.1451, Validation Loss: 0.1572
# Epoch 128/200, Training Loss: 0.1528, Validation Loss: 0.1472
# Epoch 129/200, Training Loss: 0.1441, Validation Loss: 0.1505
# Epoch 130/200, Training Loss: 0.1474, Validation Loss: 0.1359
# Epoch 131/200, Training Loss: 0.1344, Validation Loss: 0.1309
# Epoch 132/200, Training Loss: 0.1304, Validation Loss: 0.1226
# Epoch 133/200, Training Loss: 0.1227, Validation Loss: 0.1188
# Epoch 134/200, Training Loss: 0.1196, Validation Loss: 0.1163
# Epoch 135/200, Training Loss: 0.1169, Validation Loss: 0.1148
# Epoch 136/200, Training Loss: 0.1156, Validation Loss: 0.1144
# Epoch 137/200, Training Loss: 0.1150, Validation Loss: 0.1157
# Epoch 138/200, Training Loss: 0.1160, Validation Loss: 0.1186
# Epoch 139/200, Training Loss: 0.1184, Validation Loss: 0.1295
# Epoch 140/200, Training Loss: 0.1270, Validation Loss: 0.1364
# Epoch 141/200, Training Loss: 0.1332, Validation Loss: 0.1722
# Epoch 142/200, Training Loss: 0.1625, Validation Loss: 0.1543
# Epoch 143/200, Training Loss: 0.1481, Validation Loss: 0.1615
# Epoch 144/200, Training Loss: 0.1583, Validation Loss: 0.1172
# Epoch 145/200, Training Loss: 0.1209, Validation Loss: 0.1013
# Epoch 146/200, Training Loss: 0.1060, Validation Loss: 0.1006
# Epoch 147/200, Training Loss: 0.1035, Validation Loss: 0.1012
# Epoch 148/200, Training Loss: 0.1047, Validation Loss: 0.1034
# Epoch 149/200, Training Loss: 0.1046, Validation Loss: 0.1013
# Epoch 150/200, Training Loss: 0.1030, Validation Loss: 0.1038
# Epoch 151/200, Training Loss: 0.1035, Validation Loss: 0.1006
# Epoch 152/200, Training Loss: 0.1009, Validation Loss: 0.1035
# Epoch 153/200, Training Loss: 0.1022, Validation Loss: 0.0999
# Epoch 154/200, Training Loss: 0.0995, Validation Loss: 0.1041
# Epoch 155/200, Training Loss: 0.1019, Validation Loss: 0.1016
# Epoch 156/200, Training Loss: 0.1001, Validation Loss: 0.1094
# Epoch 157/200, Training Loss: 0.1059, Validation Loss: 0.1032
# Epoch 158/200, Training Loss: 0.1009, Validation Loss: 0.1101
# Epoch 159/200, Training Loss: 0.1063, Validation Loss: 0.1016
# Epoch 160/200, Training Loss: 0.0992, Validation Loss: 0.1055
# Epoch 161/200, Training Loss: 0.1022, Validation Loss: 0.0967
# Epoch 162/200, Training Loss: 0.0949, Validation Loss: 0.0969
# Epoch 163/200, Training Loss: 0.0947, Validation Loss: 0.0906
# Epoch 164/200, Training Loss: 0.0895, Validation Loss: 0.0903
# Epoch 165/200, Training Loss: 0.0890, Validation Loss: 0.0887
# Epoch 166/200, Training Loss: 0.0876, Validation Loss: 0.0911
# Epoch 167/200, Training Loss: 0.0897, Validation Loss: 0.0923
# Epoch 168/200, Training Loss: 0.0908, Validation Loss: 0.1010
# Epoch 169/200, Training Loss: 0.0982, Validation Loss: 0.1026
# Epoch 170/200, Training Loss: 0.1005, Validation Loss: 0.1180
# Epoch 171/200, Training Loss: 0.1139, Validation Loss: 0.1112
# Epoch 172/200, Training Loss: 0.1093, Validation Loss: 0.1156
# Epoch 173/200, Training Loss: 0.1152, Validation Loss: 0.0983
# Epoch 174/200, Training Loss: 0.1013, Validation Loss: 0.0867
# Epoch 175/200, Training Loss: 0.0935, Validation Loss: 0.0819
# Epoch 176/200, Training Loss: 0.0906, Validation Loss: 0.0754
# Epoch 177/200, Training Loss: 0.0877, Validation Loss: 0.0768
# Epoch 178/200, Training Loss: 0.0909, Validation Loss: 0.0727
# Epoch 179/200, Training Loss: 0.0869, Validation Loss: 0.0752
# Epoch 180/200, Training Loss: 0.0877, Validation Loss: 0.0720
# Epoch 181/200, Training Loss: 0.0818, Validation Loss: 0.0740
# Epoch 182/200, Training Loss: 0.0809, Validation Loss: 0.0748
# Epoch 183/200, Training Loss: 0.0778, Validation Loss: 0.0788
# Epoch 184/200, Training Loss: 0.0796, Validation Loss: 0.0910
# Epoch 185/200, Training Loss: 0.0875, Validation Loss: 0.0953
# Epoch 186/200, Training Loss: 0.0908, Validation Loss: 0.1174
# Epoch 187/200, Training Loss: 0.1086, Validation Loss: 0.0999
# Epoch 188/200, Training Loss: 0.0950, Validation Loss: 0.0999
# Epoch 189/200, Training Loss: 0.0957, Validation Loss: 0.0783
# Epoch 190/200, Training Loss: 0.0779, Validation Loss: 0.0677
# Epoch 191/200, Training Loss: 0.0682, Validation Loss: 0.0634
# Epoch 192/200, Training Loss: 0.0639, Validation Loss: 0.0614
# Epoch 193/200, Training Loss: 0.0628, Validation Loss: 0.0608
# Epoch 194/200, Training Loss: 0.0619, Validation Loss: 0.0600
# Epoch 195/200, Training Loss: 0.0615, Validation Loss: 0.0597
# Epoch 196/200, Training Loss: 0.0608, Validation Loss: 0.0589
# Epoch 197/200, Training Loss: 0.0602, Validation Loss: 0.0587
# Epoch 198/200, Training Loss: 0.0596, Validation Loss: 0.0584
# Epoch 199/200, Training Loss: 0.0596, Validation Loss: 0.0588
# Epoch 200/200, Training Loss: 0.0596, Validation Loss: 0.0591

# %%
y_pred = model(X_test_scaled).cpu().detach().numpy()
mse = mean_squared_error(y_test.detach().cpu().numpy(), y_pred)
print(f'Test MSE: {mse}')
history["final_test_loss"]  = mse
# Out:
# Test MSE: 56.35398483276367
